# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Grepsr/Dataset - Junior Data QA Analyst.csv', encoding='utf-8')

# %%
# Group by post_code and save each group
for post_code, group in df.groupby('post_code'):
    group.to_csv(f'/content/drive/MyDrive/Grepsr/Task 2/dataset_{post_code}.csv', index=False, encoding='utf-8')
